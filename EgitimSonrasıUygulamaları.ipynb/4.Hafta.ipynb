# %% [markdown]
# # Problem 1
# `ogrenciler` adında bir sözlük oluşturunuz. Kullanıcıdan döngü yardımıyla 3 öğrenci için veri girmesini isteyerek öğrencilerin sırasıyla okul numarası, isim, soy isim, telefon numarası ve doğum tarihi bilgilerini alınız. Aldığınız öğrenci bilgilerini yine aynı döngü yardımıyla `ogrenciler` adındaki sözlükte saklayınız. Daha sonra öğrenci bilgilerinin bulunduğu sözlük yapısını ekrana bastırınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
ogrenciler = {}
for i in range(1,4):
    okulnumara = int(input("Okul numarınız girin:"))
    name = input("İsim giriniz:")
    surname = input("Soyisim giriniz:")
    telefon = int(input("Telefon numaranızı girin: "))
    dogum = input("Doğum tarihinizi girin:")
    print("--")
    ogrenciler[i] = {
        "No" : okulnumara,
        "İsim": name,
        "Soyisim": surname,
        "Telefon" : telefon,
        "Doğum tarihi" : dogum
    }
    print(ogrenciler)
# Out:
# --
# {1: {'No': 340, 'İsim': 'selin', 'Soyisim': 'erdem', 'Telefon': 539, 'Doğum tarihi': '24062003'}}
# --
# {1: {'No': 340, 'İsim': 'selin', 'Soyisim': 'erdem', 'Telefon': 539, 'Doğum tarihi': '24062003'}, 2: {'No': 430, 'İsim': 'dilara', 'Soyisim': 'Akgün', 'Telefon': 540, 'Doğum tarihi': '28012003'}}
# --
# {1: {'No': 340, 'İsim': 'selin', 'Soyisim': 'erdem', 'Telefon': 539, 'Doğum tarihi': '24062003'}, 2: {'No': 430, 'İsim': 'dilara', 'Soyisim': 'Akgün', 'Telefon': 540, 'Doğum tarihi': '28012003'}, 3: {'No': 176, 'İsim': 'azra', 'Soyisim': 'bulut', 'Telefon': 567, 'Doğum tarihi': '11122002'}}

# %% [markdown]
# # Problem 2
#
# ### a - Biraz ısınarak başlayalım!
#
# ```
# numbers = [5,10,10,15,15,15,20,20,20,20]
# ```
#
# Yukarıda `numbers` adında 10 elemanlı bir liste verilmiştir. Bu listenin her elemanını kontrol eden ve tekrar eden elemanları bir kez olacak şekilde başka bir listeye kopyalayan bir program yazınız. Son olarak oluşturduğunuz listeyi ekrana bastırınız.
#
#
#
#
# ```
# >Output
# [5, 10, 15, 20]
# ```

# %%
# 2.Problemin a Şıkkının Çözümünü Buraya Yazınız
numbers = [5,10,10,15,15,15,20,20,20,20]
unique = []
for number in numbers: 
    if number in unique: 
        continue
    else:
        unique.append(number)
print(unique)
# Out:
# [5, 10, 15, 20]

# %% [markdown]
# ### 🌶️ b) Hadi işi biraz daha zorlaştıralım!
#
#
# Şimdiyse senden `numbers` isimli listedeki tekrar eden elemanları `repeatNumbers` adındaki listeye; tekrar etmeyen elemanları `uniqueNumbers`adındaki listeye kopyalayan yazmanı ve listeleri ekrana bastırmanı bekliyoruz
#
# ```
# >Output
# Tekrar Eden Elemanlar: [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar Etmeyen Elemanlar: [5]
# ```

# %%
# 2.Problemin b Şıkkının Çözümünü Buraya Yazınız,
numbers = [5,10,10,15,15,15,20,20,20,20]
unique = []
repeat = []
for number in numbers:
    if numbers.count(number) == 1:
        unique.append(number)
    else:
        repeat.append(number)
print("Tekrar eden elemanlar: ", repeat)
print("Tekrar etmeyen elemanlar:", unique)
# Out:
# Tekrar eden elemanlar:  [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar etmeyen elemanlar: [5]

# %% [markdown]
# # Problem 3
# sn1 = {1,2,3,4,5}
#
# sn2 = {4,5,6,7,8}
#
#  Verilen 2 adet küme için kesişimlerini, farklarını ve birleşimlerini bulunuz.

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sn1 = {1,2,3,4,5}
sn2 = {4,5,6,7,8}
kesisim = sn1.intersection(sn2)
fark1 = sn1.difference_update(sn2)
fark2 = sn2.difference_update(sn1)
birlesim = sn1.union(sn2)
print("Kesişimleri" , kesisim)
print("Sn1'in sn2'den farkı" , sn1)
print("Sn2'nin sn1'den farkı " , sn2)
print("İki kümenin birleşimi", birlesim)
# Out:
# Kesişimleri {4, 5}
# Sn1'in sn2'den farkı {1, 2, 3}
# Sn2'nin sn1'den farkı  {4, 5, 6, 7, 8}
# İki kümenin birleşimi {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# # Problem 4
#
# Buradaki işlemlerimizin tamamı stringler içindir. Aşağıda verilecek olan metodlar için kendinizin örnek yaratması gerekmektedir.
#
# Örneğin `upper` için `string` değişkeni oluştururken` k = "BAC"` şeklinde oluşturmayınız. Bunun yerine k değişkenini `k = "bac`" şeklinde oluşturmanız `upper` metodundaki değişimi görebilmeniz için daha iyi olacaktır.
#
# Bütün metodlardaki değişimin gözle görülür şekilde değişimi beklenmektedir.
#
#
# 1- capitalize(), lower(), upper(), swapcase(), title(), replace()
#
# 2- endswith(), startswith(), find(), index(), count()
#
# 3- split(), strip(), join(), islower(), isalpha(), isdigit()
#
#
# Yukarıdaki `string` metodlarındaki değişimleri görebildiğimiz bir program yazınız.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
k = "YetGen Core ile Python Öğreniyorum"
print(k)
print(k.capitalize())
print(k.lower())
print(k.upper())
print(k.swapcase())
print(k.title())
print(k.replace("Python" , "21. Yüzyıl Yetkinliklerini"))
# Out:
# YetGen Core ile Python Öğreniyorum
# Yetgen core ile python öğreniyorum
# yetgen core ile python öğreniyorum
# YETGEN CORE ILE PYTHON ÖĞRENIYORUM
# yETgEN cORE ILE pYTHON öĞRENIYORUM
# Yetgen Core Ile Python Öğreniyorum
# YetGen Core ile 21. Yüzyıl Yetkinliklerini Öğreniyorum

# %%
print(k.endswith("Öğreniyorum"))
print(k.startswith("Üniversite"))
print(k.find("Python"))
#print(k.index("Java", 5,12))
print(k.count("e"))
# Out:
# True
# False
# 16
# 5

# %%
k = "YetGen Core ile Python Öğreniyorum"
print(k.split(" "))
k = "         YetGen Core ile Python Öğreniyorum       "
k = k.strip()
print(k)

l = ("YetGen", "Core","İle", "Python", "Öğreniyorum")
print("#".join(l))
print(k.islower())
print(k.isalpha())
print(k.isdigit())
print(k.lower().islower())
# Out:
# ['YetGen', 'Core', 'ile', 'Python', 'Öğreniyorum']
# YetGen Core ile Python Öğreniyorum
# YetGen#Core#İle#Python#Öğreniyorum
# False
# False
# False
# True
